# %%
A=9.5
AA=7.5
B=265.5
BB=237.3
T=input('TempC=')
TD=input('DewC=')
e=6.1078*10**((TD*AA)/(TD+BB))
es=6.1078*10**((T*A)/(T+B))
RHi=(e/es)*100
S=RHi-100
print e-es
print'RHi: %r%s' % (RHi,'%')
print'Supersaturation: %r%s' % (S,'%')
# Out:
# TempC=-10
# DewC=-14
# -0.526019842298
# RHi: 79.72610093689705%
# Supersaturation: -20.273899063102945%

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [12.0, 9.0]
A=9.5
AA=7.5
B=265.5
BB=237.3
e=6.1078*10**((x*AA)/(x+BB))
es=6.1078*10**((x*A)/(x+B))
RHi=(e/es)*100
S=RHi-100
x = np.linspace(-20, 0)
#y = e
#y1 = es
y2=e-es
y3=(RHi)*y2
#plt.plot(x, y, 'k')
#plt.plot(x, y1, 'k')
plt.plot(x, y2, 'k')
plt.plot(x, y3, 'k')
plt.grid(True)
plt.show()
